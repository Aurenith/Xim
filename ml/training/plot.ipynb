# %%
import pandas as pd

# %%
df = pd.read_csv("../models/trained/visdrone/results.csv")

# %%
df.head(1)
# Out:
#    epoch     time    train  box_loss  train.1  cls_loss  train.2  dfl_loss  \
# 0      1  2101.17  2.04633   2.66395   1.0277   0.25408  0.14271   0.09094
#
#    metrics  precision(B)  ...  val.1  cls_loss.1  val.2  dfl_loss.1  lr  pg0  \
# 0   0.0476       1.85089  ...    NaN         NaN    NaN         NaN NaN  NaN
#
#    lr.1  pg1  lr.2  pg2
# 0   NaN  NaN   NaN  NaN
#
# [1 rows x 28 columns]
